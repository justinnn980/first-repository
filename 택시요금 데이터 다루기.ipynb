# %%
import pandas as pd  
trip = pd.read_csv('data/trip.csv')

# %%
trip
# Out:
#           passenger_name    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0           Pamela Duffy   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1        Michelle Foster   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2             Tina Combs   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3            Anthony Ray   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4        Brianna Johnson  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
# ...                  ...                     ...                     ...
# 22696     Austin Johnson   02/24/2017 5:37:23 PM   02/24/2017 5:40:39 PM
# 22697   Monique Williams   08/06/2017 4:43:59 PM   08/06/2017 5:24:47 PM
# 22698        Drew Graves   09/04/2017 2:54:14 PM   09/04/2017 2:58:22 PM
# 22699  Jonathan Copeland  07/15/2017 12:56:30 PM   07/15/2017 1:08:26 PM
# 22700    Benjamin Miller   03/02/2017 1:02:49 PM   03/02/2017 1:16:09 PM
#
#       payment_method  passenger_count  trip_distance  fare_amount  tip_amount  \
# ...

# %%
trip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22701 entries, 0 to 22700
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   passenger_name         22701 non-null  object
#  1   tpep_pickup_datetime   22701 non-null  object
#  2   tpep_dropoff_datetime  22701 non-null  object
#  3   payment_method         22701 non-null  object
#  4   passenger_count        22701 non-null  int64
#  5   trip_distance          22701 non-null  float64
#  6   fare_amount            22698 non-null  float64
#  7   tip_amount             22701 non-null  float64
#  8   tolls_amount           22701 non-null  float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 1.6+ MB

# %%
trip.describe()
# Out:
#        passenger_count  trip_distance   fare_amount    tip_amount  \
# count     22701.000000   22701.000000  22698.000000  22701.000000
# mean          1.643584       2.913400     13.024009      1.835745
# std           1.304942       3.653023     13.240074      2.800537
# min           0.000000       0.000000   -120.000000      0.000000
# 25%           1.000000       0.990000      6.500000      0.000000
# 50%           1.000000       1.610000      9.500000      1.350000
# 75%           2.000000       3.060000     14.500000      2.450000
# max          36.000000      33.960000    999.990000    200.000000
#
#        tolls_amount
# count  22701.000000
# mean       0.312514
# std        1.399153
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       19.100000

# %%
trip.isna().sum()
# Out:
# passenger_name           0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# payment_method           0
# passenger_count          0
# trip_distance            0
# fare_amount              3
# tip_amount               0
# tolls_amount             0
# dtype: int64

# %%
trip.isna().mean()
# Out:
# passenger_name           0.000000
# tpep_pickup_datetime     0.000000
# tpep_dropoff_datetime    0.000000
# payment_method           0.000000
# passenger_count          0.000000
# trip_distance            0.000000
# fare_amount              0.000132
# tip_amount               0.000000
# tolls_amount             0.000000
# dtype: float64

# %%
trip[trip['fare_amount'].isna()]
# Out:
#        passenger_name    tpep_pickup_datetime  tpep_dropoff_datetime  \
# 52   Benjamin Johnson   04/04/2017 4:22:03 PM  04/04/2017 4:35:30 PM
# 189      Maria Ibarra  08/21/2017 12:40:25 PM  08/21/2017 1:12:31 PM
# 244        Tina Avila   08/09/2017 8:32:09 AM  08/09/2017 9:31:11 AM
#
#     payment_method  passenger_count  trip_distance  fare_amount  tip_amount  \
# 52            Cash                1           2.20          NaN         0.0
# 189     Debit Card                3          15.20          NaN         5.0
# 244           Cash                1          15.89          NaN        10.0
#
#      tolls_amount
# 52           0.00
# 189          0.00
# 244          5.76

# %%
len(trip)
# Out:
# 22701

# %% [markdown]
# # 삭제

# %%
trip = trip.dropna()

# %%
len(trip)
# Out:
# 22676

# %% [markdown]
# # 시각화

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
trip['fare_amount'].sort_values()
# Out:
# 12946   -120.00
# 11206     -4.50
# 20700     -4.50
# 17604     -4.00
# 14716     -4.00
#           ...
# 12513    175.00
# 15476    200.00
# 13863    200.01
# 20314    450.00
# 8478     999.99
# Name: fare_amount, Length: 22698, dtype: float64

# %%
fig, ax = plt.subplots(ncols=3,nrows=2, figsize=(20,10))


sns.distplot(trip['passenger_count'], ax=ax[0][0])
sns.distplot(trip['fare_amount'], ax=ax[1][0])
sns.distplot(trip['trip_distance'], ax=ax[0][1])
sns.distplot(trip['tolls_amount'], ax=ax[1][1])
sns.distplot(trip['tip_amount'], ax=ax[1][2])
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
fig, ax = plt.subplots(ncols=3,nrows=2, figsize=(20,10))

sns.scatterplot(x = trip.index, y = trip['passenger_count'], ax=ax[0][0])
sns.scatterplot(x = trip.index, y = trip['fare_amount'], ax=ax[0][1])
sns.scatterplot(x = trip.index, y = trip['fare_amount'], ax=ax[1][0])
sns.scatterplot(x = trip.index, y = trip['tolls_amount'], ax=ax[1][1])
sns.scatterplot(x = trip.index, y = trip['tip_amount'], ax=ax[1][2])
# Out:
# <AxesSubplot:ylabel='tip_amount'>

# %%
trip['tip_amount'].sort_values()
# Out:
# 16784      0.00
# 8184       0.00
# 19799      0.00
# 8189       0.00
# 8192       0.00
#           ...
# 986       42.29
# 12513     46.69
# 13863     51.64
# 6066      55.50
# 8478     200.00
# Name: tip_amount, Length: 22698, dtype: float64

# %%
sns.displot(trip['tip_amount'])

# %%
sns.scatterplot(x = trip.index, y = trip['tip_amount'])
# Out:
# <AxesSubplot:ylabel='tip_amount'>

# %%
trip['tolls_amount'].sort_values()
# Out:
# 0         0.00
# 14948     0.00
# 14947     0.00
# 14946     0.00
# 14945     0.00
#          ...
# 18890    18.00
# 13361    18.00
# 4887     18.26
# 16707    18.28
# 5273     19.10
# Name: tolls_amount, Length: 22698, dtype: float64

# %%
sns.displot(trip['tolls_amount'])

# %%
sns.scatterplot(x = trip.index, y = trip['tolls_amount'])
# Out:
# <AxesSubplot:ylabel='tolls_amount'>

# %% [markdown]
# # 이상치 삭제

# %%
trip['passenger_count'].sort_values()
# Out:
# 12804     0
# 19458     0
# 5565      0
# 5670      0
# 13718     0
#          ..
# 1548      6
# 6951      6
# 20579     6
# 0         6
# 64       36
# Name: passenger_count, Length: 22678, dtype: int64

# %%
sns.displot(trip['passenger_count'])

# %%
sns.scatterplot(x = trip.index, y = trip['passenger_count'])
# Out:
# <AxesSubplot:ylabel='passenger_count'>

# %%
trip = trip[trip['passenger_count'] <= 6]

# %%
sns.scatterplot(x = trip.index, y = trip['passenger_count'])
# Out:
# <AxesSubplot:ylabel='passenger_count'>

# %%
trip = trip[trip['fare_amount'] <= 201]

# %%
trip['fare_amount'].sort_values()
# Out:
# 12946   -120.00
# 11206     -4.50
# 20700     -4.50
# 17604     -4.00
# 14716     -4.00
#           ...
# 9282     150.00
# 3584     152.00
# 12513    175.00
# 15476    200.00
# 13863    200.01
# Name: fare_amount, Length: 22696, dtype: float64

# %%
sns.scatterplot(x = trip.index, y = trip['fare_amount'])
# Out:
# <AxesSubplot:ylabel='fare_amount'>

# %%
trip = trip[trip['fare_amount'] >= 0]

# %%
sns.scatterplot(x = trip.index, y = trip['fare_amount'])
# Out:
# <AxesSubplot:ylabel='fare_amount'>

# %%
trip = trip[trip['tip_amount'] <= 40]

# %%
sns.scatterplot(x = trip.index, y = trip['tip_amount'])
# Out:
# <AxesSubplot:ylabel='tip_amount'>

# %% [markdown]
# # 카드이름 변경

# %%
trip['payment_method'].replace({'Credit Card' : 'Card', 'Debit Card' : 'Card'})
# Out:
# 0        Card
# 1        Card
# 2        Card
# 3        Cash
# 4        Card
#          ...
# 22696    Cash
# 22697    Cash
# 22698    Card
# 22699    Card
# 22700    Cash
# Name: payment_method, Length: 22691, dtype: object

# %%
trip['payment_method']
# Out:
# 0        Debit Card
# 1        Debit Card
# 2        Debit Card
# 3              Cash
# 4        Debit Card
#             ...
# 22696          Cash
# 22697          Cash
# 22698    Debit Card
# 22699    Debit Card
# 22700          Cash
# Name: payment_method, Length: 22691, dtype: object

# %% [markdown]
# # 시간데이터 이상치 삭제

# %%
from datetime import datetime

# %%
tpep_pickup_datetime

# %%
tpep_dropoff_datetime

# %%
trip['tpep_pickup_datetime'] = pd.to_datetime(trip['tpep_pickup_datetime'])

# %%
trip['tpep_dropoff_datetime'] = pd.to_datetime(trip['tpep_dropoff_datetime'])

# %%
trip['time'] = trip['tpep_dropoff_datetime'] - trip['tpep_pickup_datetime']

# %%
trip['time'].sort_values()
# Out:
# 9358    -1 days +23:43:01
# 4744      0 days 00:00:00
# 17272     0 days 00:00:00
# 5632      0 days 00:00:00
# 21838     0 days 00:00:00
#                ...
# 15165     0 days 23:58:33
# 22640     0 days 23:58:39
# 15000     0 days 23:58:51
# 15581     0 days 23:59:09
# 926       0 days 23:59:33
# Name: time, Length: 22677, dtype: timedelta64[ns]

# %%
trip = trip.drop([9358])

# %%
trip['time'].sort_values()
# Out:
# 2742    0 days 00:00:00
# 16588   0 days 00:00:00
# 8891    0 days 00:00:00
# 20640   0 days 00:00:00
# 8841    0 days 00:00:00
#               ...
# 15165   0 days 23:58:33
# 22640   0 days 23:58:39
# 15000   0 days 23:58:51
# 15581   0 days 23:59:09
# 926     0 days 23:59:33
# Name: time, Length: 22676, dtype: timedelta64[ns]

# %%
sns.scatterplot(x = trip.index, y = trip['time'])
# Out:
# <AxesSubplot:ylabel='time'>

# %%
time_arr = trip[trip.time > '00:00:00']

# %%
time_arr = trip[('00:00:00' < trip.time)& (trip.time < '06:00:00')]

# %%
time_arr['time'].sort_values()
# Out:
# 20182   0 days 00:00:01
# 2738    0 days 00:00:01
# 19638   0 days 00:00:01
# 10508   0 days 00:00:02
# 7516    0 days 00:00:02
#               ...
# 11544   0 days 01:58:52
# 820     0 days 02:09:19
# 19485   0 days 02:39:19
# 30      0 days 03:29:10
# 5053    0 days 05:32:07
# Name: time, Length: 22607, dtype: timedelta64[ns]

# %%
time_arr
# Out:
#           passenger_name tpep_pickup_datetime tpep_dropoff_datetime  \
# 0           Pamela Duffy  2017-03-25 08:55:43   2017-03-25 09:09:47
# 1        Michelle Foster  2017-04-11 14:53:28   2017-04-11 15:19:58
# 2             Tina Combs  2017-12-15 07:26:56   2017-12-15 07:34:08
# 3            Anthony Ray  2017-05-07 13:17:59   2017-05-07 13:48:14
# 4        Brianna Johnson  2017-04-15 23:32:20   2017-04-15 23:49:03
# ...                  ...                  ...                   ...
# 22696     Austin Johnson  2017-02-24 17:37:23   2017-02-24 17:40:39
# 22697   Monique Williams  2017-08-06 16:43:59   2017-08-06 17:24:47
# 22698        Drew Graves  2017-09-04 14:54:14   2017-09-04 14:58:22
# 22699  Jonathan Copeland  2017-07-15 12:56:30   2017-07-15 13:08:26
# 22700    Benjamin Miller  2017-03-02 13:02:49   2017-03-02 13:16:09
#
#       payment_method  passenger_count  trip_distance  fare_amount  tip_amount  \
# ...

# %%
time_arr['time'].sort_values()
# Out:
# 20640   0 days 00:00:00
# 2742    0 days 00:00:00
# 17272   0 days 00:00:00
# 8841    0 days 00:00:00
# 21838   0 days 00:00:00
#               ...
# 11544   0 days 01:58:52
# 820     0 days 02:09:19
# 19485   0 days 02:39:19
# 30      0 days 03:29:10
# 5053    0 days 05:32:07
# Name: time, Length: 22633, dtype: timedelta64[ns]

# %%
time_arr['time'] = pd.to_timedelta(time_arr['time'], unit='m').dt.total_seconds() / 60.0

sns.scatterplot(x=time_arr['time'], y=time_arr['fare_amount'])

plt.title('Time vs Fare')
# Out:
# /tmp/ipykernel_50/606645212.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_arr['time'] = pd.to_timedelta(time_arr['time'], unit='m').dt.total_seconds() / 60.0
# Text(0.5, 1.0, 'Time vs Fare')

# %%
time_arr['fare_amount'].sort_values()
# Out:
# 19069      0.0
# 21844      0.0
# 10508      0.0
# 5724       0.0
# 4404       0.0
#          ...
# 10293    131.0
# 16381    140.0
# 9282     150.0
# 3584     152.0
# 15476    200.0
# Name: fare_amount, Length: 22607, dtype: float64

# %% [raw]
# 회고 :
#     정리를 너무 못한거 같아서 속상하다
